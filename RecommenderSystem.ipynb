# %%
# User model based Collaborative Filtering Recommendation System

import numpy as np
import pandas as pd
import datetime

# %%
# Creating a dictionary of the mean of the ratings of each user
def find_mean(data):
    u_mean = {}
    for u_row in range(len(data.index)):
        user_id_for_mean = data.index[u_row]
        mean = pd.Series(data.ix[user_id_for_mean]).values
        mean = mean[~np.isnan(mean)].mean()
        u_mean[user_id_for_mean] = mean
    return u_mean

# %%
# Calculating Cosine similarity to find out the similar users

def cosine_similarity(u1, u2):
    u1 = np.asarray(u1)
    u2 = np.asarray(u2)
    return np.sum(u1 * u2) / np.sqrt(np.sum(u1 ** 2) * np.sum(u2 ** 2))


# Creating a dictionary of users with their corresponding similar users and their cosine similarity values.

def get_similarity(data):
    similarity = {}
    for row in range(len(data.index)):
        user_id = data.index[row]
        reviews = {}
        for x in range(len(data.index)):
            uid = data.index[x]
            if uid == user_id:
                continue
            if user_id in similarity:
                if uid in similarity[user_id]:
                    reviews[uid] = similarity[user_id][uid]
                    continue
            correlation = cosine_similarity(pd.Series(data.ix[uid]).values, pd.Series(data.ix[user_id]).values)
            reviews[uid] = correlation
            if uid in similarity:
                temp = similarity[uid]
                if bool(temp):
                    temp[user_id] = reviews[uid]
                    similarity[uid] = temp
            else:
                temp = {}
                temp[user_id] = reviews[uid]
                similarity[uid] = temp

        reviews = sorted(reviews.iteritems(), key=lambda (k, v): (v, k), reverse=True)
        similarity[user_id] = reviews
    return similarity

# %%
# Changing the training data pivot table - (actual value - mean) and insert into a new pivot table
def alter_training_data_for_similarity(data, mean):
    for index in range(len(data.index)):
        user_id_for_mean = data.index[index]
        movies_for_mean_uid = pd.Series(data.ix[user_id_for_mean]).values
        movies_for_mean_uid = [0 if np.isnan(x) else x - mean[user_id_for_mean] for x in movies_for_mean_uid]
        data.loc[user_id_for_mean] = pd.Series(movies_for_mean_uid).values
    return data

# %%
# Rating Prediction for movie 'm_id' by user 'u_id'

def predict_rating(u_id, m_id):
    global training_data
    global similarity
    user_list = similarity[u_id]
    k_users = 10 # numbers of top similar users
    numerator = 0.0
    denominator = 0.0
    for index in range(k_users):
        user_id_for_correlation = user_list[index][0]
        cor = user_list[index][1]
        for m_id_tuple in training_data.columns.tolist():
            if m_id_tuple[1] == m_id:
                r = training_data.ix[user_id_for_correlation].loc[:, m_id].values[0]
                break
            else:
                r = 0
                continue

        rating = 0 if np.isnan(r) else r
        numerator = numerator + (rating * cor)
        denominator = denominator + cor
        prediction = numerator / denominator
        if np.isnan(prediction) or prediction <= 1:
            return 1
        else:
            return int(round(prediction))

# %%
# Recommending movies to the user:
## First predict the rating of all movies which are NaN in training data by each user and then recommend the k moies 
### whose predicted rating is greater than or equal to the 80% of the mean value.

def recommendedMovies(trainingData, movies_data_1, predicted_rating, user_rating_mean, number_of_recommendation):
    user_rating_prediction = {}
    for user in predicted_rating:
        mean = user_rating_mean[user]
        movie_rating_prediction = {}
        for m in trainingData.columns.tolist():
            movie = m[1]
            if np.isnan(trainingData.ix[user].loc[:,movie].values[0]):
                movie_prediction = predict_rating(user, movie)
                if movie_prediction >= (mean*0.8):
                    movie_filter = movies_data_1[movies_data_1['movie_id'] == movie]
                    movie_name = movie_filter.get_value(movie_filter.index[0], 'movie_name')
                    movie_rating_prediction[movie] = movie_name
                if len(movie_rating_prediction) == number_of_recommendation:
                    break
        user_rating_prediction[user] = movie_rating_prediction
    return user_rating_prediction

# %%
# Finding RMSE value
def find_root_mean_square(data, predicted_ratings):
    root_mean_square = []
    for u_id_r in data.index:
        for m_id_c in data.columns.tolist():
            observed = data.ix[u_id_r].loc[:, m_id_c[1]].values[0]
            if m_id_c[1] in predicted_user_rating_for_test_data[u_id_r].keys():
                prediction = predicted_ratings[u_id_r][m_id_c[1]]
                root_mean_square.append((observed - prediction) ** 2)
    n = len(root_mean_square)
    root_mean_square = [rms for rms in root_mean_square if np.isfinite(rms)]
    return np.sqrt(np.sum(root_mean_square) / n)

# %%
# Input Files:
## movies.dat - It contains information of movies which has header - Movie_id, Movie_name and genre. 
### This file has total 3883 records
## ratings.dat - It Contains information of ratings given by users to the movies, headers - User_id, Movie_id, rating, timestamp
### This file has 900,188 records

### Ratings file has been shuffled first and then splitted into two files:
### training-data(80% of total records) and test-data(200 records)


ratings_header = ['user_id', 'movie_id', 'rating', 'timestamp']
movies_header = ['movie_id', 'movie_name', 'genre']

# %%
# Reading movies.dat and ratings_train.dat file and create a pivot_table of training data.
# Also, drop the timestamp column from ratings file because it's of no use in the computation.

movies_data = pd.read_csv('movies.dat', sep='::', names=movies_header, engine='python')
ratings = pd.read_csv('ratings_train.dat', sep='::', names=ratings_header, engine='python')
ratings.drop(['timestamp'], axis=1, inplace=True)

training_data = pd.pivot_table(ratings, index=['user_id'], columns=['movie_id'], values=['rating'])

# %%
user_mean = find_mean(training_data)

training_mean_data = alter_training_data_for_similarity(training_data.copy(), user_mean)

similarity = get_similarity(training_mean_data)
# Out:
# C:\Users\akash\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """

# %%
# Reading test data and droping the column timestamp. Creating a pivot_table of the data.
# This test data has 200 records and the format is:
## user_id, movie_id, rating, timestamp
## By using this test data we will predict the rating of each movie by user and then find the root mean square error.

test_data = pd.read_csv('ratings_test1.dat', sep="::", names=ratings_header, engine='python')
test_data.drop(['timestamp'], axis=1, inplace=True)
test_data = test_data.pivot_table(index=['user_id'], columns=['movie_id'], values=['rating'])

# %%
# Finding Root Mean Square Error against test data
predicted_user_rating_for_test_data = {}
for user_id_row in test_data.index:
    predicted_movie_rating = {}
    for movie_id_column_tuple in test_data.columns.tolist():
        movie_id_column = movie_id_column_tuple[1]
        if np.isnan(test_data.ix[user_id_row].loc[:, movie_id_column].values[0]):
            continue
        predicted_movie_rating[movie_id_column] = predict_rating(user_id_row, movie_id_column)
    predicted_user_rating_for_test_data[user_id_row] = predicted_movie_rating

rmse = find_root_mean_square(test_data, predicted_user_rating_for_test_data)
print 'Root Mean Square Error = ',rmse
# Out:
# Root Mean Square Error =  2.62488094968

# %%
# Recommending and printing movies for users
recommended_movies = recommendedMovies(training_data, movies_data, predicted_user_rating_for_test_data, user_mean, 10)

# %%
for user_recommendation in recommended_movies:
    print '(', datetime.datetime.now(), ') For User - ', user_recommendation
    print '\n' , str(recommended_movies[user_recommendation]) , '\n'
# Out:
# ( 2017-11-12 18:23:08.625000 ) For User -  5636
#
# {96L: 'In the Bleak Midwinter (1995)', 482L: 'Killing Zoe (1994)', 36L: 'Dead Man Walking (1995)', 300L: 'Quiz Show (1994)', 337L: "What's Eating Gilbert Grape (1993)", 306L: 'Three Colors: Red (1994)', 595L: 'Beauty and the Beast (1991)', 246L: 'Hoop Dreams (1994)', 537L: 'Sirens (1994)', 25L: 'Leaving Las Vegas (1995)'}
#
# ( 2017-11-12 18:23:08.848000 ) For User -  3589
#
# {32L: 'Twelve Monkeys (1995)', 2L: 'Jumanji (1995)', 43L: 'Restoration (1995)', 7L: 'Sabrina (1995)', 11L: 'American President, The (1995)', 78L: 'Crossing Guard, The (1995)', 47L: 'Seven (Se7en) (1995)', 20L: 'Money Train (1995)', 23L: 'Assassins (1995)', 39L: 'Clueless (1995)'}
#
# ( 2017-11-12 18:23:08.850000 ) For User -  4618
#
# {2528L: "Logan's Run (1976)", 1028L: 'Mary Poppins (1964)', 2188L: '54 (1998)', 1965L: 'Repo Man (1984)', 1584L: 'Contact (1997)', 1653L: 'Gattaca (1997)', 2133L: 'Adventures in Babysitting (1987)', 2010L: 'Metropolis (1926)', 2046L: 'Flight of the Navigator (1986)', 1215L: 'Army of Darkness (1993)'}
#
# ( 2017-11-12 18:23:08.852000 ) For User -  1547
#
# {1956L: 'Ordinary People (1980)', 837L: 'Matilda (1996)', 3114L: 'Toy Story 2 (1999)', 3147L: 'Green Mile, The (1999)', 2355L: "Bug's Life, A (1998)", 3255L: 'League of Their Own, A (1992)', 2431L: 'Patch Adams (1998)'}
#
# ( 2017-11-12 18:23:08.854000 ) For User -  4621
#
# {736L: 'Twister (1996)', 193L: 'Showgirls (1995)', 741L: 'Ghost in the Shell (Kokaku kidotai) (1995)', 1094L: 'Crying Game, The (1992)', 737L: 'Barb Wire (1996)', 1197L: 'Princess Bride, The (1987)', 1199L: 'Brazil (1985)', 50L: 'Usual Suspects, The (1995)', 24L: 'Powder (1995)', 1145L: 'Snowriders (1996)'}
#
# ( 2017-11-12 18:23:08.856000 ) For User -  924
#
# {1218L: 'Killer, The (Die xue shuang xiong) (1989)', 708L: 'Truth About Cats & Dogs, The (1996)', 1449L: 'Waiting for Guffman (1996)', 1387L: 'Jaws (1975)', 1196L: 'Star Wars: Episode V - The Empire Strikes Back (1980)', 1200L: 'Aliens (1986)', 2633L: 'Mummy, The (1932)', 1240L: 'Terminator, The (1984)'}
#
# ( 2017-11-12 18:23:08.858000 ) For User -  533
#
# {2L: 'Jumanji (1995)', 6L: 'Heat (1995)', 7L: 'Sabrina (1995)', 41L: 'Richard III (1995)', 34L: 'Babe (1995)', 18L: 'Four Rooms (1995)', 24L: 'Powder (1995)', 25L: 'Leaving Las Vegas (1995)', 26L: 'Othello (1995)', 29L: 'City of Lost Children, The (1995)'}
#
# ( 2017-11-12 18:23:08.860000 ) For User -  1560
#
# {608L: 'Fargo (1996)', 1090L: 'Platoon (1986)', 356L: 'Forrest Gump (1994)', 296L: 'Pulp Fiction (1994)', 1097L: 'E.T. the Extra-Terrestrial (1982)', 589L: 'Terminator 2: Judgment Day (1991)', 50L: 'Usual Suspects, The (1995)', 919L: 'Wizard of Oz, The (1939)', 260L: 'Star Wars: Episode IV - A New Hope (1977)', 858L: 'Godfather, The (1972)'}
#
# ( 2017-11-12 18:23:08.903000 ) For User -  1284
#
# {1356L: 'Star Trek: First Contact (1996)', 364L: 'Lion King, The (1994)', 1197L: 'Princess Bride, The (1987)', 1198L: 'Raiders of the Lost Ark (1981)', 47L: 'Seven (Se7en) (1995)', 50L: 'Usual Suspects, The (1995)', 595L: 'Beauty and the Beast (1991)', 282L: 'Nell (1994)', 509L: 'Piano, The (1993)', 223L: 'Clerks (1994)'}
#
# ( 2017-11-12 18:23:08.904000 ) For User -  26
#
# {34L: 'Babe (1995)', 6L: 'Heat (1995)', 10L: 'GoldenEye (1995)', 43L: 'Restoration (1995)', 16L: 'Casino (1995)', 17L: 'Sense and Sensibility (1995)', 50L: 'Usual Suspects, The (1995)', 21L: 'Get Shorty (1995)', 24L: 'Powder (1995)', 27L: 'Now and Then (1995)'}
#
# ( 2017-11-12 18:23:08.904000 ) For User -  4635
#
# {800L: 'Lone Star (1996)', 290L: 'Once Were Warriors (1994)', 164L: 'Devil in a Blue Dress (1995)', 47L: 'Seven (Se7en) (1995)', 720L: 'Wallace & Gromit: The Best of Aardman Animation (1996)', 318L: 'Shawshank Redemption, The (1994)', 213L: 'Burnt By the Sun (Utomlyonnye solntsem) (1994)', 858L: 'Godfather, The (1972)', 28L: 'Persuasion (1995)', 94L: 'Beautiful Girls (1996)'}
#
# ( 2017-11-12 18:23:08.905000 ) For User -  3620
#
# {356L: 'Forrest Gump (1994)', 165L: 'Die Hard: With a Vengeance (1995)', 7L: 'Sabrina (1995)', 105L: 'Bridges of Madison County, The (1995)', 10L: 'GoldenEye (1995)', 140L: 'Up Close and Personal (1996)', 110L: 'Braveheart (1995)', 341L: 'Double Happiness (1994)', 342L: "Muriel's Wedding (1994)", 376L: 'River Wild, The (1994)'}
#
# ( 2017-11-12 18:23:08.906000 ) For User -  4647
#
# {480L: 'Jurassic Park (1993)', 353L: 'Crow, The (1994)', 329L: 'Star Trek: Generations (1994)', 10L: 'GoldenEye (1995)', 589L: 'Terminator 2: Judgment Day (1991)', 653L: 'Dragonheart (1996)', 728L: 'Cold Comfort Farm (1995)', 246L: 'Hoop Dreams (1994)', 440L: 'Dave (1993)', 316L: 'Stargate (1994)'}
#
# ( 2017-11-12 18:23:08.906000 ) For User -  5163
#
# {160L: 'Congo (1995)', 480L: 'Jurassic Park (1993)', 1024L: 'Three Caballeros, The (1945)', 329L: 'Star Trek: Generations (1994)', 938L: 'Gigi (1958)', 173L: 'Judge Dredd (1995)', 207L: 'Walk in the Clouds, A (1995)', 924L: '2001: A Space Odyssey (1968)', 541L: 'Blade Runner (1982)', 605L: 'One Fine Day (1996)'}
#
# ( 2017-11-12 18:23:08.944000 ) For User -  1069
#
# {225L: 'Disclosure (1994)', 164L: 'Devil in a Blue Dress (1995)', 6L: 'Heat (1995)', 14L: 'Nixon (1995)', 47L: 'Seven (Se7en) (1995)', 17L: 'Sense and Sensibility (1995)', 50L: 'Usual Suspects, The (1995)', 151L: 'Rob Roy (1995)', 388L: 'Boys Life (1995)', 254L: 'Jefferson in Paris (1995)'}
#
# ( 2017-11-12 18:23:09.051000 ) For User -  1626
#
# {32L: 'Twelve Monkeys (1995)', 3L: 'Grumpier Old Men (1995)', 196L: 'Species (1995)', 198L: 'Strange Days (1995)', 327L: 'Tank Girl (1995)', 329L: 'Star Trek: Generations (1994)', 144L: 'Brothers McMullen, The (1995)', 24L: 'Powder (1995)', 316L: 'Stargate (1994)', 253L: 'Interview with the Vampire (1994)'}
#
# ( 2017-11-12 18:23:09.053000 ) For User -  92
#
# {3L: 'Grumpier Old Men (1995)', 5L: 'Father of the Bride Part II (1995)', 7L: 'Sabrina (1995)', 10L: 'GoldenEye (1995)', 11L: 'American President, The (1995)', 16L: 'Casino (1995)', 19L: 'Ace Ventura: When Nature Calls (1995)', 21L: 'Get Shorty (1995)', 25L: 'Leaving Las Vegas (1995)', 27L: 'Now and Then (1995)'}
#
# ( 2017-11-12 18:23:09.054000 ) For User -  1722
#
# {2747L: 'Little Shop of Horrors, The (1960)', 36L: 'Dead Man Walking (1995)', 70L: 'From Dusk Till Dawn (1996)', 1961L: 'Rain Man (1988)', 912L: 'Casablanca (1942)', 2867L: 'Fright Night (1985)', 3081L: 'Sleepy Hollow (1999)', 2633L: 'Mummy, The (1932)', 2328L: 'Vampires (1998)', 1339L: "Bram Stoker's Dracula (1992)"}
#
# ( 2017-11-12 18:23:09.101000 ) For User -  1119
#
# {1249L: 'Nikita (La Femme Nikita) (1990)', 3L: 'Grumpier Old Men (1995)', 196L: 'Species (1995)', 1286L: 'Somewhere in Time (1980)', 1544L: 'Lost World: Jurassic Park, The (1997)', 329L: 'Star Trek: Generations (1994)', 524L: 'Rudy (1993)', 1617L: 'L.A. Confidential (1997)', 1396L: 'Sneakers (1992)', 24L: 'Powder (1995)'}
#
# ( 2017-11-12 18:23:09.105000 ) For User -  2145
#
# {1L: 'Toy Story (1995)', 163L: 'Desperado (1995)', 327L: 'Tank Girl (1995)', 457L: 'Fugitive, The (1993)', 110L: 'Braveheart (1995)', 21L: 'Get Shorty (1995)', 377L: 'Speed (1994)', 380L: 'True Lies (1994)', 29L: 'City of Lost Children, The (1995)', 318L: 'Shawshank Redemption, The (1994)'}
#
# ( 2017-11-12 18:23:09.107000 ) For User -  2146
#
# {898L: 'Philadelphia Story, The (1940)', 771L: 'Vie est belle, La (Life is Rosey) (1987)', 1256L: 'Duck Soup (1933)', 905L: 'It Happened One Night (1934)', 1196L: 'Star Wars: Episode V - The Empire Strikes Back (1980)', 1230L: 'Annie Hall (1977)', 1103L: 'Rebel Without a Cause (1955)', 1136L: 'Monty Python and the Holy Grail (1974)', 1201L: 'Good, The Bad and The Ugly, The (1966)', 1203L: '12 Angry Men (1957)'}
#
# ( 2017-11-12 18:23:09.150000 ) For User -  3684
#
# {2724L: 'Runaway Bride (1999)', 2565L: 'King and I, The (1956)', 1612L: 'Kiss Me, Guido (1997)', 2996L: 'Music of the Heart (1999)', 2390L: 'Little Voice (1998)', 24L: 'Powder (1995)', 2907L: 'Superstar (1999)', 2908L: "Boys Don't Cry (1999)", 2333L: 'Gods and Monsters (1998)', 2686L: 'Red Violin, The (Le Violon rouge) (1998)'}
#
# ( 2017-11-12 18:23:09.152000 ) For User -  1125
#
# {1193L: "One Flew Over the Cuckoo's Nest (1975)", 1198L: 'Raiders of the Lost Ark (1981)', 527L: "Schindler's List (1993)", 1136L: 'Monty Python and the Holy Grail (1974)', 1873L: 'Mis\xe9rables, Les (1998)', 1619L: 'Seven Years in Tibet (1997)', 1205L: 'Transformers: The Movie, The (1986)', 1302L: 'Field of Dreams (1989)', 1688L: 'Anastasia (1997)', 1274L: 'Akira (1988)'}
#
# ( 2017-11-12 18:23:09.155000 ) For User -  103
#
# {2916L: 'Total Recall (1990)', 1097L: 'E.T. the Extra-Terrestrial (1982)', 2571L: 'Matrix, The (1999)', 2353L: 'Enemy of the State (1998)', 3062L: 'Longest Day, The (1962)', 3256L: 'Patriot Games (1992)'}
#
# ( 2017-11-12 18:23:09.158000 ) For User -  4714
#
# {1088L: 'Dirty Dancing (1987)', 290L: 'Once Were Warriors (1994)', 293L: 'Professional, The (a.k.a. Leon: The Professional) (1994)', 904L: 'Rear Window (1954)', 110L: 'Braveheart (1995)', 593L: 'Silence of the Lambs, The (1991)', 1042L: 'That Thing You Do! (1996)', 597L: 'Pretty Woman (1990)', 377L: 'Speed (1994)', 318L: 'Shawshank Redemption, The (1994)'}
#
# ( 2017-11-12 18:23:09.160000 ) For User -  1639
#
# {208L: 'Waterworld (1995)', 3L: 'Grumpier Old Men (1995)', 164L: 'Devil in a Blue Dress (1995)', 230L: 'Dolores Claiborne (1994)', 70L: 'From Dusk Till Dawn (1996)', 225L: 'Disclosure (1994)', 10L: 'GoldenEye (1995)', 16L: 'Casino (1995)', 81L: "Things to Do in Denver when You're Dead (1995)", 151L: 'Rob Roy (1995)'}
#
# ( 2017-11-12 18:23:09.162000 ) For User -  113
#
# {514L: 'Ref, The (1994)', 3L: 'Grumpier Old Men (1995)', 551L: 'Nightmare Before Christmas, The (1993)', 745L: 'Close Shave, A (1995)', 908L: 'North by Northwest (1959)', 1035L: 'Sound of Music, The (1965)', 524L: 'Rudy (1993)', 589L: 'Terminator 2: Judgment Day (1991)', 89L: 'Nick of Time (1995)', 858L: 'Godfather, The (1972)'}
#
# ( 2017-11-12 18:23:09.164000 ) For User -  117
#
# {112L: 'Rumble in the Bronx (1995)', 2L: 'Jumanji (1995)', 70L: 'From Dusk Till Dawn (1996)', 76L: 'Screamers (1995)', 13L: 'Balto (1995)', 48L: 'Pocahontas (1995)', 145L: 'Bad Boys (1995)', 185L: 'Net, The (1995)', 24L: 'Powder (1995)', 89L: 'Nick of Time (1995)'}
#
# ( 2017-11-12 18:23:09.167000 ) For User -  120
#
# {742L: 'Thinner (1996)', 70L: 'From Dusk Till Dawn (1996)', 1128L: 'Fog, The (1980)', 1097L: 'E.T. the Extra-Terrestrial (1982)', 879L: 'Relic, The (1997)', 532L: 'Serial Mom (1994)', 724L: 'Craft, The (1996)', 188L: 'Prophecy, The (1995)', 382L: 'Wolf (1994)', 735L: 'Cemetery Man (Dellamorte Dellamore) (1994)'}
#
# ( 2017-11-12 18:23:09.169000 ) For User -  5249
#
# {736L: 'Twister (1996)', 1L: 'Toy Story (1995)', 260L: 'Star Wars: Episode IV - A New Hope (1977)', 5L: 'Father of the Bride Part II (1995)', 587L: 'Ghost (1990)', 589L: 'Terminator 2: Judgment Day (1991)', 786L: 'Eraser (1996)', 20L: 'Money Train (1995)', 248L: 'Houseguest (1994)', 62L: "Mr. Holland's Opus (1995)"}
#
# ( 2017-11-12 18:23:09
', 260L: 'Star Wars: Episode IV - A New Hope (1977)', 1246L: 'Dead Poets Society (1989)', 1215L: 'Army of Darkness (1993)'}
#
# ( 2017-11-12 18:23:09.236000 ) For User -  4279
#
# {507L: 'Perfect World, A (1993)', 6L: 'Heat (1995)', 423L: 'Blown Away (1994)', 168L: 'First Knight (1995)', 653L: 'Dragonheart (1996)', 366L: "Wes Craven's New Nightmare (1994)", 367L: 'Mask, The (1994)', 504L: 'No Escape (1994)', 111L: 'Taxi Driver (1976)', 220L: 'Castle Freak (1995)'}
#
# ( 2017-11-12 18:23:09.238000 ) For User -  698
#
# {36L: 'Dead Man Walking (1995)', 70L: 'From Dusk Till Dawn (1996)', 10L: 'GoldenEye (1995)', 45L: 'To Die For (1995)', 47L: 'Seven (Se7en) (1995)', 17L: 'Sense and Sensibility (1995)', 50L: 'Usual Suspects, The (1995)', 52L: 'Mighty Aphrodite (1995)', 21L: 'Get Shorty (1995)', 57L: 'Home for the Holidays (1995)'}
#
# ( 2017-11-12 18:23:09.239000 ) For User -  4285
#
# {161L: 'Crimson Tide (1995)', 163L: 'Desperado (1995)', 293L: 'Professional, The (a.k.a. Leon: The Professional) (1994)', 6L: 'Heat (1995)', 236L: 'French Kiss (1995)', 47L: 'Seven (Se7en) (1995)', 144L: 'Brothers McMullen, The (1995)', 50L: 'Usual Suspects, The (1995)', 253L: 'Interview with the Vampire (1994)', 223L: 'Clerks (1994)'}
#
# ( 2017-11-12 18:23:09.239000 ) For User -  1727
#
# {34L: 'Babe (1995)', 164L: 'Devil in a Blue Dress (1995)', 390L: 'Faster Pussycat! Kill! Kill! (1965)', 6L: 'Heat (1995)', 110L: 'Braveheart (1995)', 112L: 'Rumble in the Bronx (1995)', 50L: 'Usual Suspects, The (1995)', 52L: 'Mighty Aphrodite (1995)', 345L: 'Adventures of Priscilla, Queen of the Desert, The (1994)', 349L: 'Clear and Present Danger (1994)'}
#
# ( 2017-11-12 18:23:09.240000 ) For User -  5824
#
# {32L: 'Twelve Monkeys (1995)', 34L: 'Babe (1995)', 3L: 'Grumpier Old Men (1995)', 14L: 'Nixon (1995)', 16L: 'Casino (1995)', 17L: 'Sense and Sensibility (1995)', 22L: 'Copycat (1995)', 24L: 'Powder (1995)', 25L: 'Leaving Las Vegas (1995)', 27L: 'Now and Then (1995)'}
#
# ( 2017-11-12 18:23:09.241000 ) For User -  2241
#
# {260L: 'Star Wars: Episode IV - A New Hope (1977)', 935L: 'Band Wagon, The (1953)', 919L: 'Wizard of Oz, The (1939)', 909L: 'Apartment, The (1960)', 910L: 'Some Like It Hot (1959)', 944L: 'Lost Horizon (1937)', 755L: 'Kim (1950)', 917L: 'Little Princess, The (1939)', 599L: 'Wild Bunch, The (1969)', 858L: 'Godfather, The (1972)'}
#
# ( 2017-11-12 18:23:09.242000 ) For User -  2242
#
# {1954L: 'Rocky (1976)', 1270L: 'Back to the Future (1985)', 934L: 'Father of the Bride (1950)', 10L: 'GoldenEye (1995)', 2000L: 'Lethal Weapon (1987)', 145L: 'Bad Boys (1995)', 1587L: 'Conan the Barbarian (1982)', 1334L: 'Blob, The (1958)', 1240L: 'Terminator, The (1984)', 1722L: 'Tomorrow Never Dies (1997)'}
#
# ( 2017-11-12 18:23:09.242000 ) For User -  4291
#
# {288L: 'Natural Born Killers (1994)', 165L: 'Die Hard: With a Vengeance (1995)', 168L: 'First Knight (1995)', 10L: 'GoldenEye (1995)', 44L: 'Mortal Kombat (1995)', 349L: 'Clear and Present Danger (1994)', 360L: 'I Love Trouble (1994)', 21L: 'Get Shorty (1995)', 316L: 'Stargate (1994)', 170L: 'Hackers (1995)'}
#
# ( 2017-11-12 18:23:09.256000 ) For User -  708
#
# {480L: 'Jurassic Park (1993)', 551L: 'Nightmare Before Christmas, The (1993)', 1544L: 'Lost World: Jurassic Park, The (1997)', 1035L: 'Sound of Music, The (1965)', 1198L: 'Raiders of the Lost Ark (1981)', 2160L: "Rosemary's Baby (1968)", 3534L: '28 Days (2000)', 1080L: "Monty Python's Life of Brian (1979)", 1721L: 'Titanic (1997)', 3101L: 'Fatal Attraction (1987)'}
#
# ( 2017-11-12 18:23:09.256000 ) For User -  5317
#
# {161L: 'Crimson Tide (1995)', 2L: 'Jumanji (1995)', 36L: 'Dead Man Walking (1995)', 107L: 'Muppet Treasure Island (1996)', 46L: 'How to Make an American Quilt (1995)', 47L: 'Seven (Se7en) (1995)', 112L: 'Rumble in the Bronx (1995)', 117L: "Young Poisoner's Handbook, The (1995)", 151L: 'Rob Roy (1995)', 29L: 'City of Lost Children, The (1995)'}
#
# ( 2017-11-12 18:23:09.258000 ) For User -  710
#
# {259L: 'Kiss of Death (1995)', 260L: 'Star Wars: Episode IV - A New Hope (1977)', 262L: 'Little Princess, A (1995)', 70L: 'From Dusk Till Dawn (1996)', 10L: 'GoldenEye (1995)', 171L: 'Jeffrey (1995)', 79L: 'Juror, The (1996)', 47L: 'Seven (Se7en) (1995)', 42L: 'Dead Presidents (1995)', 222L: 'Circle of Friends (1995)'}
#
# ( 2017-11-12 18:23:09.272000 ) For User -  1225
#
# {3175L: 'Galaxy Quest (1999)', 940L: 'Adventures of Robin Hood, The (1938)', 908L: 'North by Northwest (1959)', 1196L: 'Star Wars: Episode V - The Empire Strikes Back (1980)', 86L: 'White Squall (1996)', 1848L: 'Borrowers, The (1997)', 2617L: 'Mummy, The (1999)', 314L: 'Secret of Roan Inish, The (1994)', 29L: 'City of Lost Children, The (1995)', 94L: 'Beautiful Girls (1996)'}
#
# ( 2017-11-12 18:23:09.273000 ) For User -  3274
#
# {674L: 'Barbarella (1968)', 709L: 'Oliver & Company (1988)', 391L: "Jason's Lyric (1994)", 616L: 'Aristocats, The (1970)', 239L: 'Goofy Movie, A (1995)', 595L: 'Beauty and the Beast (1991)', 596L: 'Pinocchio (1940)', 24L: 'Powder (1995)', 788L: 'Nutty Professor, The (1996)', 111L: 'Taxi Driver (1976)'}
#
# ( 2017-11-12 18:23:09.274000 ) For User -  1741
#
# {451L: 'Flesh and Bone (1993)', 616L: 'Aristocats, The (1970)', 745L: 'Close Shave, A (1995)', 588L: 'Aladdin (1992)', 367L: 'Mask, The (1994)', 720L: 'Wallace & Gromit: The Best of Aardman Animation (1996)', 594L: 'Snow White and the Seven Dwarfs (1937)', 595L: 'Beauty and the Beast (1991)', 596L: 'Pinocchio (1940)', 661L: 'James and the Giant Peach (1996)'}
#
# ( 2017-11-12 18:23:09.275000 ) For User -  4815
#
# {416L: 'Bad Girls (1994)', 357L: 'Four Weddings and a Funeral (1994)', 39L: 'Clueless (1995)', 265L: 'Like Water for Chocolate (Como agua para chocolate) (1992)', 471L: 'Hudsucker Proxy, The (1994)', 589L: 'Terminator 2: Judgment Day (1991)', 590L: 'Dances with Wolves (1990)', 497L: 'Much Ado About Nothing (1993)', 457L: 'Fugitive, The (1993)', 377L: 'Speed (1994)'}
#
# ( 2017-11-12 18:23:09.276000 ) For User -  3280
#
# {97L: 'Hate (Haine, La) (1995)', 34L: 'Babe (1995)', 6L: 'Heat (1995)', 92L: 'Mary Reilly (1996)', 45L: 'To Die For (1995)', 46L: 'How to Make an American Quilt (1995)', 47L: 'Seven (Se7en) (1995)', 17L: 'Sense and Sensibility (1995)', 24L: 'Powder (1995)', 60L: 'Indian in the Cupboard, The (1995)'}
#
# ( 2017-11-12 18:23:09.277000 ) For User -  721
#
# {163L: 'Desperado (1995)', 132L: 'Jade (1995)', 70L: 'From Dusk Till Dawn (1996)', 103L: 'Unforgettable (1996)', 200L: 'Tie That Binds, The (1995)', 170L: 'Hackers (1995)', 207L: 'Walk in the Clouds, A (1995)', 145L: 'Bad Boys (1995)', 20L: 'Money Train (1995)', 86L: 'White Squall (1996)'}
#
# ( 2017-11-12 18:23:09.288000 ) For User -  2772
#
# {608L: 'Fargo (1996)', 1089L: 'Reservoir Dogs (1992)', 356L: 'Forrest Gump (1994)', 1233L: 'Boat, The (Das Boot) (1981)', 457L: 'Fugitive, The (1993)', 1196L: 'Star Wars: Episode V - The Empire Strikes Back (1980)', 110L: 'Braveheart (1995)', 527L: "Schindler's List (1993)", 593L: 'Silence of the Lambs, The (1991)', 541L: 'Blade Runner (1982)'}
#
# ( 2017-11-12 18:23:09.290000 ) For User -  3285
#
# {32L: 'Twelve Monkeys (1995)', 1L: 'Toy Story (1995)', 34L: 'Babe (1995)', 3L: 'Grumpier Old Men (1995)', 69L: 'Friday (1995)', 41L: 'Richard III (1995)', 10L: 'GoldenEye (1995)', 110L: 'Braveheart (1995)', 17L: 'Sense and Sensibility (1995)', 62L: "Mr. Holland's Opus (1995)"}
#
# ( 2017-11-12 18:23:09.291000 ) For User -  5853
#
# {608L: 'Fargo (1996)', 481L: 'Kalifornia (1993)', 162L: 'Crumb (1994)', 70L: 'From Dusk Till Dawn (1996)', 551L: 'Nightmare Before Christmas, The (1993)', 482L: 'Killing Zoe (1994)', 370L: 'Naked Gun 33 1/3: The Final Insult (1994)', 246L: 'Hoop Dreams (1994)', 538L: 'Six Degrees of Separation (1993)', 29L: 'City of Lost Children, The (1995)'}
#
# ( 2017-11-12 18:23:09.291000 ) For User -  1758
#
# {163L: 'Desperado (1995)', 101L: 'Bottle Rocket (1996)', 6L: 'Heat (1995)', 266L: 'Legends of the Fall (1994)', 205L: 'Unstrung Heroes (1995)', 47L: 'Seven (Se7en) (1995)', 259L: 'Kiss of Death (1995)', 52L: 'Mighty Aphrodite (1995)', 249L: 'Immortal Beloved (1994)', 26L: 'Othello (1995)'}
#
# ( 2017-11-12 18:23:09.292000 ) For User -  736
#
# {34L: 'Babe (1995)', 101L: 'Bottle Rocket (1996)', 913L: 'Maltese Falcon, The (1941)', 778L: 'Trainspotting (1996)', 750L: 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)', 29L: 'City of Lost Children, The (1995)', 785L: 'Kingpin (1996)', 924L: '2001: A Space Odyssey (1968)', 541L: 'Blade Runner (1982)', 318L: 'Shawshank Redemption, The (1994)'}
#
# ( 2017-11-12 18:23:09.292000 ) For User -  3792
#
# {64L: 'Two if by Sea (1996)', 36L: 'Dead Man Walking (1995)', 6L: 'Heat (1995)', 7L: 'Sabrina (1995)', 105L: 'Bridges of Madison County, The (1995)', 140L: 'Up Close and Personal (1996)', 48L: 'Pocahontas (1995)', 122L: 'Boomerang (1992)', 60L: 'Indian in the Cupboard, The (1995)', 61L: 'Eye for an Eye (1996)'}
#
# ( 2017-11-12 18:23:09.346000 ) For User -  4834
#
# {5L: 'Father of the Bride Part II (1995)', 6L: 'Heat (1995)', 7L: 'Sabrina (1995)', 11L: 'American President, The (1995)', 14L: 'Nixon (1995)', 16L: 'Casino (1995)', 18L: 'Four Rooms (1995)', 22L: 'Copycat (1995)', 27L: 'Now and Then (1995)', 29L: 'City of Lost Children, The (1995)'}
#
# ( 2017-11-12 18:23:09
', 60L: 'Indian in the Cupboard, The (1995)'}
#
# ( 2017-11-12 18:23:09.416000 ) For User -  1790
#
# {65L: 'Bio-Dome (1996)', 34L: 'Babe (1995)', 70L: 'From Dusk Till Dawn (1996)', 6L: 'Heat (1995)', 47L: 'Seven (Se7en) (1995)', 88L: 'Black Sheep (1996)', 22L: 'Copycat (1995)', 23L: 'Assassins (1995)', 24L: 'Powder (1995)', 25L: 'Leaving Las Vegas (1995)'}
#
# ( 2017-11-12 18:23:09.418000 ) For User -  4352
#
# {36L: 'Dead Man Walking (1995)', 39L: 'Clueless (1995)', 10L: 'GoldenEye (1995)', 14L: 'Nixon (1995)', 47L: 'Seven (Se7en) (1995)', 18L: 'Four Rooms (1995)', 52L: 'Mighty Aphrodite (1995)', 21L: 'Get Shorty (1995)', 25L: 'Leaving Las Vegas (1995)', 62L: "Mr. Holland's Opus (1995)"}
#
# ( 2017-11-12 18:23:09.420000 ) For User -  1969
#
# {101L: 'Bottle Rocket (1996)', 6L: 'Heat (1995)', 50L: 'Usual Suspects, The (1995)', 45L: 'To Die For (1995)', 16L: 'Casino (1995)', 81L: "Things to Do in Denver when You're Dead (1995)", 18L: 'Four Rooms (1995)', 89L: 'Nick of Time (1995)', 25L: 'Leaving Las Vegas (1995)', 111L: 'Taxi Driver (1976)'}
#
# ( 2017-11-12 18:23:09.421000 ) For User -  2820
#
# {1L: 'Toy Story (1995)', 34L: 'Babe (1995)', 235L: 'Ed Wood (1994)', 141L: 'Birdcage, The (1996)', 110L: 'Braveheart (1995)', 239L: 'Goofy Movie, A (1995)', 81L: "Things to Do in Denver when You're Dead (1995)", 180L: 'Mallrats (1995)', 14L: 'Nixon (1995)', 29L: 'City of Lost Children, The (1995)'}
#
# ( 2017-11-12 18:23:09.422000 ) For User -  774
#
# {2L: 'Jumanji (1995)', 104L: 'Happy Gilmore (1996)', 10L: 'GoldenEye (1995)', 34L: 'Babe (1995)', 48L: 'Pocahontas (1995)', 20L: 'Money Train (1995)', 22L: 'Copycat (1995)', 52L: 'Mighty Aphrodite (1995)', 29L: 'City of Lost Children, The (1995)', 62L: "Mr. Holland's Opus (1995)"}
#
# ( 2017-11-12 18:23:09.424000 ) For User -  5900
#
# {1L: 'Toy Story (1995)', 293L: 'Professional, The (a.k.a. Leon: The Professional) (1994)', 39L: 'Clueless (1995)', 72L: 'Kicking and Screaming (1995)', 337L: "What's Eating Gilbert Grape (1993)", 17L: 'Sense and Sensibility (1995)', 497L: 'Much Ado About Nothing (1993)', 58L: 'Postino, Il (The Postman) (1994)', 509L: 'Piano, The (1993)', 318L: 'Shawshank Redemption, The (1994)'}
#
# ( 2017-11-12 18:23:09.425000 ) For User -  45
#
# {898L: 'Philadelphia Story, The (1940)', 3L: 'Grumpier Old Men (1995)', 356L: 'Forrest Gump (1994)', 265L: 'Like Water for Chocolate (Como agua para chocolate) (1992)', 276L: 'Milk Money (1994)', 597L: 'Pretty Woman (1990)', 361L: 'It Could Happen to You (1994)', 539L: 'Sleepless in Seattle (1993)', 380L: 'True Lies (1994)', 222L: 'Circle of Friends (1995)'}
#
# ( 2017-11-12 18:23:09.426000 ) For User -  1296
#
# {1189L: 'Thin Blue Line, The (1988)', 262L: 'Little Princess, A (1995)', 2730L: 'Barry Lyndon (1975)', 1527L: 'Fifth Element, The (1997)', 531L: 'Secret Garden, The (1993)', 595L: 'Beauty and the Beast (1991)', 919L: 'Wizard of Oz, The (1939)', 986L: 'Fly Away Home (1996)', 60L: 'Indian in the Cupboard, The (1995)'}
#
# ( 2017-11-12 18:23:09.427000 ) For User -  5393
#
# {261L: 'Little Women (1994)', 647L: 'Courage Under Fire (1996)', 73L: 'Mis\xe9rables, Les (1995)', 266L: 'Legends of the Fall (1994)', 428L: 'Bronx Tale, A (1993)', 605L: 'One Fine Day (1996)', 309L: 'Red Firecracker, Green Firecracker (1994)', 265L: 'Like Water for Chocolate (Como agua para chocolate) (1992)', 362L: 'Jungle Book, The (1994)', 21L: 'Get Shorty (1995)'}
#
# ( 2017-11-12 18:23:09.428000 ) For User -  1298
#
# {32L: 'Twelve Monkeys (1995)', 901L: 'Funny Face (1957)', 6L: 'Heat (1995)', 903L: 'Vertigo (1958)', 296L: 'Pulp Fiction (1994)', 266L: 'Legends of the Fall (1994)', 368L: 'Maverick (1994)', 17L: 'Sense and Sensibility (1995)', 902L: "Breakfast at Tiffany's (1961)", 599L: 'Wild Bunch, The (1969)'}
#
# ( 2017-11-12 18:23:09.429000 ) For User -  2323
#
# {480L: 'Jurassic Park (1993)', 353L: 'Crow, The (1994)', 357L: 'Four Weddings and a Funeral (1994)', 6L: 'Heat (1995)', 969L: 'African Queen, The (1951)', 555L: 'True Romance (1993)', 110L: 'Braveheart (1995)', 112L: 'Rumble in the Bronx (1995)', 592L: 'Batman (1989)', 377L: 'Speed (1994)'}
#
# ( 2017-11-12 18:23:09.431000 ) For User -  1308
#
# {802L: 'Phenomenon (1996)', 1061L: 'Sleepers (1996)', 104L: 'Happy Gilmore (1996)', 1097L: 'E.T. the Extra-Terrestrial (1982)', 720L: 'Wallace & Gromit: The Best of Aardman Animation (1996)', 529L: 'Searching for Bobby Fischer (1993)', 150L: 'Apollo 13 (1995)', 700L: 'Angus (1995)', 861L: 'Supercop (1992)', 671L: 'Mystery Science Theater 3000: The Movie (1996)'}
#
# ( 2017-11-12 18:23:09.432000 ) For User -  3358
#
# {1089L: 'Reservoir Dogs (1992)', 296L: 'Pulp Fiction (1994)', 553L: 'Tombstone (1993)', 908L: 'North by Northwest (1959)', 590L: 'Dances with Wolves (1990)', 592L: 'Batman (1989)', 18L: 'Four Rooms (1995)', 919L: 'Wizard of Oz, The (1939)', 25L: 'Leaving Las Vegas (1995)', 349L: 'Clear and Present Danger (1994)'}
#
# ( 2017-11-12 18:23:09.644000 ) For User -  4386
#
# {3L: 'Grumpier Old Men (1995)', 36L: 'Dead Man Walking (1995)', 69L: 'Friday (1995)', 6L: 'Heat (1995)', 111L: 'Taxi Driver (1976)', 145L: 'Bad Boys (1995)', 20L: 'Money Train (1995)', 22L: 'Copycat (1995)', 89L: 'Nick of Time (1995)', 61L: 'Eye for an Eye (1996)'}
#
# ( 2017-11-12 18:23:09.646000 ) For User -  293
#
# {32L: 'Twelve Monkeys (1995)', 35L: 'Carrington (1995)', 36L: 'Dead Man Walking (1995)', 7L: 'Sabrina (1995)', 11L: 'American President, The (1995)', 16L: 'Casino (1995)', 21L: 'Get Shorty (1995)', 25L: 'Leaving Las Vegas (1995)', 26L: 'Othello (1995)', 39L: 'Clueless (1995)'}
#
# ( 2017-11-12 18:23:09.648000 ) For User -  4907
#
# {416L: 'Bad Girls (1994)', 356L: 'Forrest Gump (1994)', 357L: 'Four Weddings and a Funeral (1994)', 39L: 'Clueless (1995)', 265L: 'Like Water for Chocolate (Como agua para chocolate) (1992)', 471L: 'Hudsucker Proxy, The (1994)', 497L: 'Much Ado About Nothing (1993)', 457L: 'Fugitive, The (1993)', 377L: 'Speed (1994)', 541L: 'Blade Runner (1982)'}
#
# ( 2017-11-12 18:23:09.650000 ) For User -  1324
#
# {480L: 'Jurassic Park (1993)', 356L: 'Forrest Gump (1994)', 805L: 'Time to Kill, A (1996)', 454L: 'Firm, The (1993)', 62L: "Mr. Holland's Opus (1995)", 150L: 'Apollo 13 (1995)', 1271L: 'Fried Green Tomatoes (1991)', 932L: 'Affair to Remember, An (1957)', 350L: 'Client, The (1994)', 1343L: 'Cape Fear (1991)'}
#
# ( 2017-11-12 18:23:09.652000 ) For User -  1326
#
# {2628L: 'Star Wars: Episode I - The Phantom Menace (1999)', 293L: 'Professional, The (a.k.a. Leon: The Professional) (1994)', 1704L: 'Good Will Hunting (1997)', 1961L: 'Rain Man (1988)', 1580L: 'Men in Black (1997)', 1197L: 'Princess Bride, The (1987)', 589L: 'Terminator 2: Judgment Day (1991)', 17L: 'Sense and Sensibility (1995)'}
#
# ( 2017-11-12 18:23:09.654000 ) For User -  3377
#
# {480L: 'Jurassic Park (1993)', 34L: 'Babe (1995)', 356L: 'Forrest Gump (1994)', 497L: 'Much Ado About Nothing (1993)', 457L: 'Fugitive, The (1993)', 588L: 'Aladdin (1992)', 17L: 'Sense and Sensibility (1995)', 150L: 'Apollo 13 (1995)', 553L: 'Tombstone (1993)', 508L: 'Philadelphia (1993)'}
#
# ( 2017-11-12 18:23:09.657000 ) For User -  307
#
# {356L: 'Forrest Gump (1994)', 934L: 'Father of the Bride (1950)', 39L: 'Clueless (1995)', 1197L: 'Princess Bride, The (1987)', 110L: 'Braveheart (1995)', 17L: 'Sense and Sensibility (1995)', 594L: 'Snow White and the Seven Dwarfs (1937)', 25L: 'Leaving Las Vegas (1995)', 1210L: 'Star Wars: Episode VI - Return of the Jedi (1983)', 508L: 'Philadelphia (1993)'}
#
# ( 2017-11-12 18:23:09.660000 ) For User -  820
#
# {354L: 'Cobb (1994)', 387L: 'Low Down Dirty Shame, A (1994)', 356L: 'Forrest Gump (1994)', 2321L: 'Pleasantville (1998)', 1640L: 'How to Be a Player (1997)', 1500L: 'Grosse Pointe Blank (1997)', 1265L: 'Groundhog Day (1993)', 2772L: 'Detroit Rock City (1999)', 1784L: 'As Good As It Gets (1997)', 380L: 'True Lies (1994)'}
#
# ( 2017-11-12 18:23:09.663000 ) For User -  4405
#
# {912L: 'Casablanca (1942)', 969L: 'African Queen, The (1951)', 940L: 'Adventures of Robin Hood, The (1938)', 429L: 'Cabin Boy (1994)', 110L: 'Braveheart (1995)', 592L: 'Batman (1989)', 150L: 'Apollo 13 (1995)', 345L: 'Adventures of Priscilla, Queen of the Desert, The (1994)', 348L: 'Bullets Over Broadway (1994)', 350L: 'Client, The (1994)'}
#
# ( 2017-11-12 18:23:09.688000 ) For User -  310
#
', 52L: 'Mighty Aphrodite (1995)', 21L: 'Get Shorty (1995)', 25L: 'Leaving Las Vegas (1995)'}
#
# ( 2017-11-12 18:23:09.707000 ) For User -  836
#
# {480L: 'Jurassic Park (1993)', 6L: 'Heat (1995)', 616L: 'Aristocats, The (1970)', 457L: 'Fugitive, The (1993)', 589L: 'Terminator 2: Judgment Day (1991)', 1009L: 'Escape to Witch Mountain (1975)', 1013L: 'Parent Trap, The (1961)', 377L: 'Speed (1994)', 733L: 'Rock, The (1996)', 158L: 'Casper (1995)'}
#
# ( 2017-11-12 18:23:09.710000 ) For User -  5450
#
# {897L: 'For Whom the Bell Tolls (1943)', 923L: 'Citizen Kane (1941)', 904L: 'Rear Window (1954)', 589L: 'Terminator 2: Judgment Day (1991)', 750L: 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)', 527L: "Schindler's List (1993)", 50L: 'Usual Suspects, The (1995)', 950L: 'Thin Man, The (1934)', 25L: 'Leaving Las Vegas (1995)', 111L: 'Taxi Driver (1976)'}
#
# ( 2017-11-12 18:23:09.711000 ) For User -  2018
#
# {176L: 'Living in Oblivion (1995)', 105L: 'Bridges of Madison County, The (1995)', 107L: 'Muppet Treasure Island (1996)', 111L: 'Taxi Driver (1976)', 48L: 'Pocahontas (1995)', 246L: 'Hoop Dreams (1994)', 247L: 'Heavenly Creatures (1994)', 239L: 'Goofy Movie, A (1995)', 125L: 'Flirting With Disaster (1996)', 62L: "Mr. Holland's Opus (1995)"}
#
# ( 2017-11-12 18:23:09.712000 ) For User -  1364
#
# {260L: 'Star Wars: Episode IV - A New Hope (1977)', 1193L: "One Flew Over the Cuckoo's Nest (1975)", 235L: 'Ed Wood (1994)', 909L: 'Apartment, The (1960)', 1230L: 'Annie Hall (1977)', 1235L: 'Harold and Maude (1971)', 1269L: 'Arsenic and Old Lace (1944)', 1206L: 'Clockwork Orange, A (1971)', 1079L: 'Fish Called Wanda, A (1988)', 1276L: 'Cool Hand Luke (1967)'}
#
# ( 2017-11-12 18:23:09.714000 ) For User -  2389
#
# {1L: 'Toy Story (1995)', 34L: 'Babe (1995)', 164L: 'Devil in a Blue Dress (1995)', 293L: 'Professional, The (a.k.a. Leon: The Professional) (1994)', 356L: 'Forrest Gump (1994)', 11L: 'American President, The (1995)', 110L: 'Braveheart (1995)', 339L: 'While You Were Sleeping (1995)', 440L: 'Dave (1993)', 260L: 'Star Wars: Episode IV - A New Hope (1977)'}
#
# ( 2017-11-12 18:23:09.715000 ) For User -  3414
#
# {258L: "Kid in King Arthur's Court, A (1995)", 292L: 'Outbreak (1995)', 107L: 'Muppet Treasure Island (1996)', 333L: 'Tommy Boy (1995)', 370L: 'Naked Gun 33 1/3: The Final Insult (1994)', 468L: 'Englishman Who Went Up a Hill, But Came Down a Mountain, The (1995)', 150L: 'Apollo 13 (1995)', 23L: 'Assassins (1995)', 252L: 'I.Q. (1994)', 62L: "Mr. Holland's Opus (1995)"}
#
# ( 2017-11-12 18:23:09.717000 ) For User -  3927
#
# {2944L: 'Dirty Dozen, The (1967)', 1193L: "One Flew Over the Cuckoo's Nest (1975)", 1198L: 'Raiders of the Lost Ark (1981)', 1201L: 'Good, The Bad and The Ugly, The (1966)', 3508L: 'Outlaw Josey Wales, The (1976)', 110L: 'Braveheart (1995)', 3702L: 'Mad Max (1979)', 3703L: 'Mad Max 2 (a.k.a. The Road Warrior) (1981)', 1240L: 'Terminator, The (1984)', 3836L: "Kelly's Heroes (1970)"}
#
# ( 2017-11-12 18:23:09.718000 ) For User -  856
#
# {3948L: 'Meet the Parents (2000)', 2158L: 'Henry: Portrait of a Serial Killer, Part 2 (1996)', 3950L: 'Tigerland (2000)', 2769L: 'Yards, The (1999)', 117L: "Young Poisoner's Handbook, The (1995)", 3893L: 'Nurse Betty (2000)'}
#
# ( 2017-11-12 18:23:09.719000 ) For User -  2907
#
# ...
#
# ( 2017-11-12 18:23:09.815000 ) For User -  3476
#
# {2L: 'Jumanji (1995)', 5L: 'Father of the Bride Part II (1995)', 39L: 'Clueless (1995)', 11L: 'American President, The (1995)', 13L: 'Balto (1995)', 112L: 'Rumble in the Bronx (1995)', 7L: 'Sabrina (1995)', 135L: 'Down Periscope (1996)', 60L: 'Indian in the Cupboard, The (1995)', 95L: 'Broken Arrow (1996)'}
#
# ( 2017-11-12 18:23:09.818000 ) For User -  1941
#
# {162L: 'Crumb (1994)', 99L: 'Heidi Fleiss: Hollywood Madam (1995)', 147L: 'Basketball Diaries, The (1995)', 6L: 'Heat (1995)', 9L: 'Sudden Death (1995)', 44L: 'Mortal Kombat (1995)', 145L: 'Bad Boys (1995)', 131L: 'Frankie Starlight (1995)', 105L: 'Bridges of Madison County, The (1995)', 24L: 'Powder (1995)'}
#
# ( 2017-11-12 18:23:09.819000 ) For User -  2454
#
# {32L: 'Twelve Monkeys (1995)', 3L: 'Grumpier Old Men (1995)', 4L: 'Waiting to Exhale (1995)', 70L: 'From Dusk Till Dawn (1996)', 6L: 'Heat (1995)', 104L: 'Happy Gilmore (1996)', 47L: 'Seven (Se7en) (1995)', 16L: 'Casino (1995)', 50L: 'Usual Suspects, The (1995)', 95L: 'Broken Arrow (1996)'}
#
# ( 2017-11-12 18:23:09.823000 ) For User -  2456
#
# {32L: 'Twelve Monkeys (1995)', 161L: 'Crimson Tide (1995)', 165L: 'Die Hard: With a Vengeance (1995)', 104L: 'Happy Gilmore (1996)', 11L: 'American President, The (1995)', 110L: 'Braveheart (1995)', 147L: 'Basketball Diaries, The (1995)', 180L: 'Mallrats (1995)', 151L: 'Rob Roy (1995)', 95L: 'Broken Arrow (1996)'}
#
# ( 2017-11-12 18:23:09.825000 ) For User -  5956
#
# {34L: 'Babe (1995)', 899L: "Singin' in the Rain (1952)", 262L: 'Little Princess, A (1995)', 546L: 'Super Mario Bros. (1993)', 17L: 'Sense and Sensibility (1995)', 914L: 'My Fair Lady (1964)', 531L: 'Secret Garden, The (1993)', 661L: 'James and the Giant Peach (1996)', 918L: 'Meet Me in St. Louis (1944)', 953L: "It's a Wonderful Life (1946)"}
#
# ( 2017-11-12 18:23:09.828000 ) For User -  5530
#
# {100L: 'City Hall (1996)', 3L: 'Grumpier Old Men (1995)', 36L: 'Dead Man Walking (1995)', 6L: 'Heat (1995)', 41L: 'Richard III (1995)', 10L: 'GoldenEye (1995)', 47L: 'Seven (Se7en) (1995)', 18L: 'Four Rooms (1995)', 21L: 'Get Shorty (1995)', 25L: 'Leaving Las Vegas (1995)'}
#
# ( 2017-11-12 18:23:09.830000 ) For User -  3483
#
# {32L: 'Twelve Monkeys (1995)', 592L: 'Batman (1989)', 356L: 'Forrest Gump (1994)', 586L: 'Home Alone (1990)', 364L: 'Lion King, The (1994)', 527L: "Schindler's List (1993)", 208L: 'Waterworld (1995)', 596L: 'Pinocchio (1940)', 316L: 'Stargate (1994)', 318L: 'Shawshank Redemption, The (1994)'}
#
# ( 2017-11-12 18:23:09.832000 ) For User -  5532
#
# {608L: 'Fargo (1996)', 928L: 'Rebecca (1940)', 1089L: 'Reservoir Dogs (1992)', 904L: 'Rear Window (1954)', 589L: 'Terminator 2: Judgment Day (1991)', 912L: 'Casablanca (1942)', 593L: 'Silence of the Lambs, The (1991)', 1240L: 'Terminator, The (1984)', 924L: '2001: A Space Odyssey (1968)', 1214L: 'Alien (1979)'}
#
# ( 2017-11-12 18:23:09.834000 ) For User -  3998
#
# {160L: 'Congo (1995)', 454L: 'Firm, The (1993)', 422L: 'Blink (1994)', 296L: 'Pulp Fiction (1994)', 457L: 'Fugitive, The (1993)', 111L: 'Taxi Driver (1976)', 50L: 'Usual Suspects, The (1995)', 373L: 'Red Rock West (1992)', 47L: 'Seven (Se7en) (1995)', 349L: 'Clear and Present Danger (1994)'}
#
# ( 2017-11-12 18:23:09.839000 ) For User -  2629
#
# {2808L: 'Universal Soldier (1992)', 1193L: "One Flew Over the Cuckoo's Nest (1975)"}
#
# ( 2017-11-12 18:23:09.841000 ) For User -  1441
#
# {34L: 'Babe (1995)', 36L: 'Dead Man Walking (1995)', 162L: 'Crumb (1994)', 111L: 'Taxi Driver (1976)', 208L: 'Waterworld (1995)', 50L: 'Usual Suspects, The (1995)', 246L: 'Hoop Dreams (1994)', 154L: 'Belle de jour (1967)', 188L: 'Prophecy, The (1995)', 253L: 'Interview with the Vampire (1994)'}
#
# ( 2017-11-12 18:23:09.842000 ) For User -  1958
#
# {161L: 'Crimson Tide (1995)', 2L: 'Jumanji (1995)', 69L: 'Friday (1995)', 70L: 'From Dusk Till Dawn (1996)', 11L: 'American President, The (1995)', 34L: 'Babe (1995)', 111L: 'Taxi Driver (1976)', 50L: 'Usual Suspects, The (1995)', 180L: 'Mallrats (1995)', 293L: 'Professional, The (a.k.a. Leon: The Professional) (1994)'}
#
# ( 2017-11-12 18:23:09.844000 ) For User -  5545
#
# {1185L: 'My Left Foot (1989)', 1267L: 'Manchurian Candidate, The (1962)', 1131L: 'Jean de Florette (1986)', 1292L: 'Being There (1979)', 1230L: 'Annie Hall (1977)', 1203L: '12 Angry Men (1957)', 1942L: "All the King's Men (1949)", 858L: 'Godfather, The (1972)', 1084L: 'Bonnie and Clyde (1967)', 1950L: 'In the Heat of the Night (1967)'}
#
# ( 2017-11-12 18:23:09.845000 ) For User -  1457
#
# {356L: 'Forrest Gump (1994)', 230L: 'Dolores Claiborne (1994)', 296L: 'Pulp Fiction (1994)', 587L: 'Ghost (1990)', 337L: "What's Eating Gilbert Grape (1993)", 919L: 'Wizard of Oz, The (1939)', 246L: 'Hoop Dreams (1994)', 151L: 'Rob Roy (1995)', 920L: 'Gone with the Wind (1939)', 474L: 'In the Line of Fire (1993)'}
#
# ( 2017-11-12 18:23:09.847000 ) For User -  5042
#
# {1L: 'Toy Story (1995)', 162L: 'Crumb (1994)', 6L: 'Heat (1995)', 50L: 'Usual Suspects, The (1995)', 93L: 'Vampire in Brooklyn (1995)', 112L: 'Rumble in the Bronx (1995)', 18L: 'Four Rooms (1995)', 52L: 'Mighty Aphrodite (1995)', 21L: 'Get Shorty (1995)', 29L: 'City of Lost Children, The (1995)'}
#
# ( 2017-11-12 18:23:09
Microcosmos (Microcosmos: Le peuple de l'herbe) (1996)"}
#
# ( 2017-11-12 18:23:09.879000 ) For User -  980
#
# {8L: 'Tom and Huck (1995)', 44L: 'Mortal Kombat (1995)', 208L: 'Waterworld (1995)', 104L: 'Happy Gilmore (1996)', 185L: 'Net, The (1995)', 56L: 'Kids of the Round Table (1995)', 153L: 'Batman Forever (1995)', 250L: 'Heavyweights (1994)', 216L: 'Billy Madison (1995)', 95L: 'Broken Arrow (1996)'}
#
# ( 2017-11-12 18:23:09.880000 ) For User -  2041
#
# {70L: 'From Dusk Till Dawn (1996)', 12L: 'Dracula: Dead and Loving It (1995)', 48L: 'Pocahontas (1995)', 49L: 'When Night Is Falling (1995)', 18L: 'Four Rooms (1995)', 21L: 'Get Shorty (1995)', 25L: 'Leaving Las Vegas (1995)', 26L: 'Othello (1995)', 60L: 'Indian in the Cupboard, The (1995)', 85L: 'Angels and Insects (1995)'}
#
# ( 2017-11-12 18:23:09.880000 ) For User -  474
#
# {32L: 'Twelve Monkeys (1995)', 42L: 'Dead Presidents (1995)', 44L: 'Mortal Kombat (1995)', 110L: 'Braveheart (1995)', 47L: 'Seven (Se7en) (1995)', 18L: 'Four Rooms (1995)', 20L: 'Money Train (1995)', 22L: 'Copycat (1995)', 24L: 'Powder (1995)', 111L: 'Taxi Driver (1976)'}
#
# ( 2017-11-12 18:23:09.881000 ) For User -  5083
#
# {69L: 'Friday (1995)', 7L: 'Sabrina (1995)', 104L: 'Happy Gilmore (1996)', 141L: 'Birdcage, The (1996)', 111L: 'Taxi Driver (1976)', 88L: 'Black Sheep (1996)', 94L: 'Beautiful Girls (1996)', 24L: 'Powder (1995)', 57L: 'Home for the Holidays (1995)', 62L: "Mr. Holland's Opus (1995)"}
#
# ( 2017-11-12 18:23:09.881000 ) For User -  3550
#
# {32L: 'Twelve Monkeys (1995)', 97L: 'Hate (Haine, La) (1995)', 39L: 'Clueless (1995)', 42L: 'Dead Presidents (1995)', 45L: 'To Die For (1995)', 19L: 'Ace Ventura: When Nature Calls (1995)', 52L: 'Mighty Aphrodite (1995)', 21L: 'Get Shorty (1995)', 86L: 'White Squall (1996)', 25L: 'Leaving Las Vegas (1995)'}
#
# ( 2017-11-12 18:23:10.384000 ) For User -  4575
#
# {1L: 'Toy Story (1995)', 3L: 'Grumpier Old Men (1995)', 164L: 'Devil in a Blue Dress (1995)', 161L: 'Crimson Tide (1995)', 10L: 'GoldenEye (1995)', 110L: 'Braveheart (1995)', 207L: 'Walk in the Clouds, A (1995)', 222L: 'Circle of Friends (1995)', 151L: 'Rob Roy (1995)', 62L: "Mr. Holland's Opus (1995)"}
#
# ( 2017-11-12 18:23:10.386000 ) For User -  5090
#
# {34L: 'Babe (1995)', 741L: 'Ghost in the Shell (Kokaku kidotai) (1995)', 457L: 'Fugitive, The (1993)', 555L: 'True Romance (1993)', 527L: "Schindler's List (1993)", 720L: 'Wallace & Gromit: The Best of Aardman Animation (1996)', 50L: 'Usual Suspects, The (1995)', 246L: 'Hoop Dreams (1994)', 29L: 'City of Lost Children, The (1995)', 671L: 'Mystery Science Theater 3000: The Movie (1996)'}
#
# ( 2017-11-12 18:23:10.387000 ) For User -  4579
#
# {2L: 'Jumanji (1995)', 4L: 'Waiting to Exhale (1995)', 6L: 'Heat (1995)', 11L: 'American President, The (1995)', 14L: 'Nixon (1995)', 16L: 'Casino (1995)', 21L: 'Get Shorty (1995)', 22L: 'Copycat (1995)', 25L: 'Leaving Las Vegas (1995)', 26L: 'Othello (1995)'}
#
# ( 2017-11-12 18:23:10.388000 ) For User -  5093
#
# {34L: 'Babe (1995)', 1221L: 'Godfather: Part II, The (1974)', 902L: "Breakfast at Tiffany's (1961)", 1193L: "One Flew Over the Cuckoo's Nest (1975)", 1041L: 'Secrets & Lies (1996)', 1208L: 'Apocalypse Now (1979)', 249L: 'Immortal Beloved (1994)', 1213L: 'GoodFellas (1990)', 318L: 'Shawshank Redemption, The (1994)', 1247L: 'Graduate, The (1967)'}
#
# ( 2017-11-12 18:23:10.388000 ) For User -  5108
#
# {260L: 'Star Wars: Episode IV - A New Hope (1977)', 262L: 'Little Princess, A (1995)', 10L: 'GoldenEye (1995)', 13L: 'Balto (1995)', 110L: 'Braveheart (1995)', 246L: 'Hoop Dreams (1994)', 356L: 'Forrest Gump (1994)', 380L: 'True Lies (1994)', 586L: 'Home Alone (1990)', 318L: 'Shawshank Redemption, The (1994)'}
#
# ( 2017-11-12 18:23:10.389000 ) For User -  5621
#
# {32L: 'Twelve Monkeys (1995)', 36L: 'Dead Man Walking (1995)', 104L: 'Happy Gilmore (1996)', 10L: 'GoldenEye (1995)', 141L: 'Birdcage, The (1996)', 110L: 'Braveheart (1995)', 16L: 'Casino (1995)', 19L: 'Ace Ventura: When Nature Calls (1995)', 58L: 'Postino, Il (The Postman) (1994)', 94L: 'Beautiful Girls (1996)'}
#
# ( 2017-11-12 18:23:10.389000 ) For User -  1449
#
# {196L: 'Species (1995)', 69L: 'Friday (1995)', 41L: 'Richard III (1995)', 272L: 'Madness of King George, The (1994)', 52L: 'Mighty Aphrodite (1995)', 21L: 'Get Shorty (1995)', 150L: 'Apollo 13 (1995)', 247L: 'Heavenly Creatures (1994)', 316L: 'Stargate (1994)', 62L: "Mr. Holland's Opus (1995)"}
#
# ( 2017-11-12 18:23:10.389000 ) For User -  3648
#
# {34L: 'Babe (1995)', 203L: 'To Wong Foo, Thanks for Everything! Julie Newmar (1995)', 230L: 'Dolores Claiborne (1994)', 6L: 'Heat (1995)', 135L: 'Down Periscope (1996)', 234L: 'Exit to Eden (1994)', 39L: 'Clueless (1995)', 112L: 'Rumble in the Bronx (1995)', 151L: 'Rob Roy (1995)', 60L: 'Indian in the Cupboard, The (1995)'}
#
# ( 2017-11-12 18:23:10.390000 ) For User -  4089
#
# {195L: 'Something to Talk About (1995)', 168L: 'First Knight (1995)', 10L: 'GoldenEye (1995)', 118L: 'If Lucy Fell (1996)', 151L: 'Rob Roy (1995)', 216L: 'Billy Madison (1995)', 218L: 'Boys on the Side (1995)', 60L: 'Indian in the Cupboard, The (1995)', 62L: "Mr. Holland's Opus (1995)", 31L: 'Dangerous Minds (1995)'}
#
# ( 2017-11-12 18:23:10.390000 ) For User -  1022
#
# {480L: 'Jurassic Park (1993)', 1959L: 'Out of Africa (1985)', 2700L: 'South Park: Bigger, Longer and Uncut (1999)', 2188L: '54 (1998)', 2541L: 'Cruel Intentions (1999)', 2670L: 'Run Silent, Run Deep (1958)', 1968L: 'Breakfast Club, The (1985)', 913L: 'Maltese Falcon, The (1941)', 2580L: 'Go (1999)', 86L: 'White Squall (1996)'}
